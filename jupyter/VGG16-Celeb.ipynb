# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import tarfile
tfile = tarfile.open("/content/gdrive/My Drive/Deep Learning Groupwork/Project/Data-Celeb.tar")
tfile.extractall()

# %%
training_dir = '/content/Data-Celeb/Train'
val_dir = '/content/Data-Celeb/Validation'
finetunedir = '/content/Data-Celeb/FineTune'
testdir = '/content/Data-Celeb/Test'

# %%
import os
from os import listdir
from os.path import isfile, join
mypath = '/content/Data-Celeb/Test/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/Test/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")
mypath = '/content/Data-Celeb/Train/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/Train/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/Validation/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/Validation/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/FineTune/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/FineTune/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")
# Out:
# /content/Data-Celeb/Test/Fake
# /content/Data-Celeb/Test/Real
# /content/Data-Celeb/Train/Fake
# /content/Data-Celeb/Train/Real
# /content/Data-Celeb/Validation/Real
# /content/Data-Celeb/Validation/Fake
# /content/Data-Celeb/FineTune/Real
# /content/Data-Celeb/FineTune/Fake

# %%
import os
os.chdir('/content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet')
print(os.getcwd())
# Out:
# /content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet

# %%
# !python3 pretrain.py -network='vgg16' -train_dir='/content/Data-Celeb/Train' -val_dir='/content/Data-Celeb/Validation' -batch_size=128 -reduce_patience=100 -step=200 -epochs=100
# Out:
# Using TensorFlow backend.
# 2020-04-26 20:47:00.209609: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 20:47:03.028223: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-26 20:47:03.081746: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 20:47:03.082781: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-26 20:47:03.082839: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 20:47:03.342429: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 20:47:03.470856: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-26 20:47:03.506344: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-26 20:47:03.776632: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-26 20:47:03.824502: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-26 20:47:04.329251: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-26 20:47:04.329482: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 20:47:04.330513: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 20:47:04.331376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-26 20:47:04.357241: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-04-26 20:47:04.357476: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2566bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-26 20:47:04.357514: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-26 20:47:04.535245: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 20:47:04.536299: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2566d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-26 20:47:04.536334: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-04-26 20:47:04.537438: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 20:47:04.538318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-26 20:47:04.538379: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 20:47:04.538424: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 20:47:04.538462: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-26 20:47:04.538499: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-26 20:47:04.538536: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-26 20:47:04.538572: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-26 20:47:04.538606: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-26 20:47:04.538718: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 20:47:04.539647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 20:47:04.540492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-26 20:47:04.544729: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 20:47:11.085176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-26 20:47:11.085234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-04-26 20:47:11.085259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-04-26 20:47:11.092440: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 20:47:11.093434: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 20:47:11.094307: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-26 20:47:11.094409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14974 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              8392704
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 8194
# =================================================================
# Total params: 39,896,898
# Trainable params: 39,896,898
# Non-trainable params: 0
# _________________________________________________________________
# 32
# Found 93051 images belonging to 2 classes.
# Found 21333 images belonging to 2 classes.
# Epoch 1/100
# 2020-04-26 20:47:16.680415: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 20:47:18.140251: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 200/200 [==============================] - 38s 189ms/step - loss: 0.6933 - accuracy: 0.5012 - val_loss: 0.6959 - val_accuracy: 0.3794
# Epoch 2/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.6931 - accuracy: 0.5043 - val_loss: 0.6845 - val_accuracy: 0.6206
# Epoch 3/100
# 200/200 [==============================] - 30s 150ms/step - loss: 0.6932 - accuracy: 0.4972 - val_loss: 0.6951 - val_accuracy: 0.3794
# Epoch 4/100
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6932 - accuracy: 0.4966 - val_loss: 0.6959 - val_accuracy: 0.3794
# Epoch 5/100
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6932 - accuracy: 0.4998 - val_loss: 0.6858 - val_accuracy: 0.6206
# Epoch 6/100
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6932 - accuracy: 0.5009 - val_loss: 0.6958 - val_accuracy: 0.3794
# Epoch 7/100
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6977 - val_accuracy: 0.3794
# Epoch 8/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.6932 - accuracy: 0.4934 - val_loss: 0.6899 - val_accuracy: 0.6206
# Epoch 9/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.6932 - accuracy: 0.4989 - val_loss: 0.6949 - val_accuracy: 0.3794
# Epoch 10/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.6932 - accuracy: 0.5010 - val_loss: 0.6866 - val_accuracy: 0.6206
# Epoch 11/100
# 200/200 [==============================] - 30s 148ms/step - loss: 0.6932 - accuracy: 0.4986 - val_loss: 0.6920 - val_accuracy: 0.6206
# Epoch 12/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.6932 - accuracy: 0.5004 - val_loss: 0.6926 - val_accuracy: 0.6206
# Epoch 13/100
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6932 - accuracy: 0.5025 - val_loss: 0.6883 - val_accuracy: 0.6206
# Epoch 14/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.6932 - accuracy: 0.4988 - val_loss: 0.6946 - val_accuracy: 0.3794
# Epoch 15/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6909 - val_accuracy: 0.6206
# Epoch 16/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.6932 - accuracy: 0.4939 - val_loss: 0.6904 - val_accuracy: 0.6206
# Epoch 17/100
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6932 - accuracy: 0.4968 - val_loss: 0.6946 - val_accuracy: 0.3794
# Epoch 18/100
# 200/200 [==============================] - 29s 147ms/step - loss: 0.6932 - accuracy: 0.5001 - val_loss: 0.7006 - val_accuracy: 0.3794
# Epoch 19/100
# 200/200 [==============================] - 29s 147ms/step - loss: 0.6932 - accuracy: 0.4964 - val_loss: 0.6990 - val_accuracy: 0.3794
# Epoch 20/100
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6932 - accuracy: 0.4966 - val_loss: 0.7000 - val_accuracy: 0.3794
# Epoch 21/100
# 200/200 [==============================] - 29s 147ms/step - loss: 0.6932 - accuracy: 0.4966 - val_loss: 0.6935 - val_accuracy: 0.3794
# Epoch 22/100
# 200/200 [==============================] - 30s 148ms/step - loss: 0.6931 - accuracy: 0.5016 - val_loss: 0.6843 - val_accuracy: 0.6206

# %%
# !python3 test.py -test_dir='/content/Data-Celeb/Test' -model='/content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet/models/weights-vgg16-celeb'
# Out:
# 2020-04-27 01:31:49.297364: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Found 25648 images belonging to 2 classes.
# 2020-04-27 01:31:53.857610: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-27 01:31:53.900269: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 01:31:53.900851: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-27 01:31:53.900892: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-27 01:31:54.153228: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-27 01:31:54.277242: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-27 01:31:54.310520: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-27 01:31:54.582006: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-27 01:31:54.639678: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-27 01:31:55.155641: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-27 01:31:55.155838: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 01:31:55.156616: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 01:31:55.157186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-27 01:31:55.208940: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-04-27 01:31:55.209155: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x14eef40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-27 01:31:55.209198: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-27 01:31:55.351816: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 01:31:55.352818: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x14eed80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-27 01:31:55.352860: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-04-27 01:31:55.354118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 01:31:55.354812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-27 01:31:55.354892: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-27 01:31:55.354956: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-27 01:31:55.354997: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-27 01:31:55.355027: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-27 01:31:55.355050: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-27 01:31:55.355074: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-27 01:31:55.355099: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-27 01:31:55.355178: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 01:31:55.355935: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 01:31:55.356631: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-27 01:31:55.521079: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-27 01:32:01.949773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-27 01:32:01.949827: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-04-27 01:32:01.949841: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-04-27 01:32:01.954549: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 01:32:01.955227: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 01:32:01.955862: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-27 01:32:01.955908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14974 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-04-27 01:32:11.342709: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-27 01:32:12.796188: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 201/201 [==============================] - 11s 54ms/step
# [[0.496 0.504]
#  [0.496 0.504]
#  [0.496 0.504]
#  ...
#  [0.496 0.504]
#  [0.496 0.504]
#  [0.496 0.504]]
# 100% 201/201 [00:23<00:00,  8.51it/s]
# [1 1 1 ... 1 1 1]
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     12982
#            1       0.49      1.00      0.66     12666
#
#     accuracy                           0.49     25648
#    macro avg       0.25      0.50      0.33     25648
# weighted avg       0.24      0.49      0.33     25648
#
# [[    0 12982]
#  [    0 12666]]
# AUROC: 0.500000
# 1.004450112581253
# test_acc:  0.49383967560823455

# %%
# !python3 fdft.py -model='/content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet/models/weights-vgg16-celeb' -ft_dir='/content/Data-Celeb/FineTune' -val_dir='/content/Data-Celeb/Validation' -network='vgg16' -test_dir='/content/Data-Celeb/Test'
# Out:
# 2020-04-28 13:12:04.214416: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Found 2003 images belonging to 2 classes.
# Found 22196 images belonging to 2 classes.
# 2020-04-28 13:12:18.907031: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-28 13:12:18.946145: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 13:12:18.947152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-28 13:12:18.947223: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-28 13:12:19.197138: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-28 13:12:19.341270: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-28 13:12:19.368623: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-28 13:12:19.646177: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-28 13:12:19.671439: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-28 13:12:20.204274: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-28 13:12:20.204548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 13:12:20.205620: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 13:12:20.206463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-28 13:12:20.253505: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-04-28 13:12:20.253793: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2060d80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-28 13:12:20.253833: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-28 13:12:20.391902: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 13:12:20.393153: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2060bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-28 13:12:20.393195: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-04-28 13:12:20.394056: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 13:12:20.394965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-28 13:12:20.395025: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-28 13:12:20.395093: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-28 13:12:20.395139: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-28 13:12:20.395185: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-28 13:12:20.395239: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-28 13:12:20.395288: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-28 13:12:20.395332: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-28 13:12:20.395498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 13:12:20.396502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 13:12:20.397501: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-28 13:12:20.400214: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-28 13:12:26.760689: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-28 13:12:26.760745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-04-28 13:12:26.760766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-04-28 13:12:26.765303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 13:12:26.766302: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 13:12:26.767238: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-28 13:12:26.767296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14974 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# <tensorflow.python.keras.engine.training.Model object at 0x7ff219823cf8>
# (1, 1, 32, 4)
# (1, 1, 64, 8)
# (1, 1, 96, 12)
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# vgg16 (Model)                   (None, 2, 2, 512)    14714688    input_1[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 576)          1619456     vgg16[1][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 576)          85710       input_1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 576)          0           model_1[1][0]
#                                                                  model_2[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1154        add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2)            0           dense_1[0][0]
# ==================================================================================================
# Total params: 16,421,008
# Trainable params: 16,408,080
# Non-trainable params: 12,928
# __________________________________________________________________________________________________
# Epoch 1/100
# 2020-04-28 13:13:06.168354: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-28 13:13:07.639574: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 200/200 [==============================] - 89s 447ms/step - loss: 0.6861 - acc: 0.6313 - val_loss: 1.0217 - val_acc: 0.3786
# Epoch 2/100
# 200/200 [==============================] - 73s 365ms/step - loss: 0.5693 - acc: 0.7328 - val_loss: 2.7967 - val_acc: 0.3789
# Epoch 3/100
# 200/200 [==============================] - 71s 357ms/step - loss: 0.3603 - acc: 0.8520 - val_loss: 1.3294 - val_acc: 0.4738
# Epoch 4/100
# 200/200 [==============================] - 73s 366ms/step - loss: 0.3115 - acc: 0.8754 - val_loss: 0.0506 - val_acc: 0.8620
# Epoch 5/100
# 200/200 [==============================] - 72s 358ms/step - loss: 0.2869 - acc: 0.8852 - val_loss: 1.5892 - val_acc: 0.7019
# Epoch 6/100
# 200/200 [==============================] - 73s 364ms/step - loss: 0.2695 - acc: 0.8938 - val_loss: 0.9113 - val_acc: 0.8332
# Epoch 7/100
# 200/200 [==============================] - 71s 356ms/step - loss: 0.2532 - acc: 0.9008 - val_loss: 0.2412 - val_acc: 0.8945
# Epoch 8/100
# 200/200 [==============================] - 73s 363ms/step - loss: 0.2378 - acc: 0.9056 - val_loss: 0.1464 - val_acc: 0.8932
# Epoch 9/100
# 200/200 [==============================] - 71s 357ms/step - loss: 0.2177 - acc: 0.9165 - val_loss: 0.1557 - val_acc: 0.8983
# Epoch 10/100
# 200/200 [==============================] - 72s 360ms/step - loss: 0.2094 - acc: 0.9187 - val_loss: 3.0866 - val_acc: 0.6725
# Epoch 11/100
# 200/200 [==============================] - 71s 355ms/step - loss: 0.1895 - acc: 0.9298 - val_loss: 0.5402 - val_acc: 0.9016
# Epoch 12/100
# 200/200 [==============================] - 72s 359ms/step - loss: 0.1820 - acc: 0.9311 - val_loss: 0.8315 - val_acc: 0.9016
# Epoch 13/100
# 200/200 [==============================] - 70s 351ms/step - loss: 0.1715 - acc: 0.9360 - val_loss: 0.1763 - val_acc: 0.9015
# Epoch 14/100
# 200/200 [==============================] - 72s 360ms/step - loss: 0.1610 - acc: 0.9406 - val_loss: 0.0776 - val_acc: 0.8964
# Epoch 15/100
# 200/200 [==============================] - 71s 353ms/step - loss: 0.1512 - acc: 0.9436 - val_loss: 0.1278 - val_acc: 0.8936
# Epoch 16/100
# 200/200 [==============================] - 73s 363ms/step - loss: 0.1492 - acc: 0.9464 - val_loss: 0.4445 - val_acc: 0.8982
# Epoch 17/100
# 200/200 [==============================] - 71s 355ms/step - loss: 0.1372 - acc: 0.9490 - val_loss: 0.0647 - val_acc: 0.8808
# Epoch 18/100
# 200/200 [==============================] - 73s 363ms/step - loss: 0.1290 - acc: 0.9540 - val_loss: 1.6811 - val_acc: 0.9030
# Epoch 19/100
# 200/200 [==============================] - 71s 354ms/step - loss: 0.1205 - acc: 0.9564 - val_loss: 0.1817 - val_acc: 0.8944
# Epoch 20/100
# 200/200 [==============================] - 73s 366ms/step - loss: 0.1164 - acc: 0.9574 - val_loss: 0.1303 - val_acc: 0.9052
# Epoch 21/100
# 200/200 [==============================] - 72s 360ms/step - loss: 0.1087 - acc: 0.9622 - val_loss: 0.2209 - val_acc: 0.9068
# Epoch 22/100
# 200/200 [==============================] - 74s 371ms/step - loss: 0.1070 - acc: 0.9612 - val_loss: 0.3664 - val_acc: 0.9131
# Epoch 23/100
# 200/200 [==============================] - 72s 361ms/step - loss: 0.1038 - acc: 0.9622 - val_loss: 0.7735 - val_acc: 0.9161
# Epoch 24/100
# 200/200 [==============================] - 74s 369ms/step - loss: 0.0948 - acc: 0.9666 - val_loss: 0.4517 - val_acc: 0.9097
# Epoch 25/100
# 200/200 [==============================] - 72s 360ms/step - loss: 0.0881 - acc: 0.9684 - val_loss: 0.2458 - val_acc: 0.9080
# Epoch 26/100
# 200/200 [==============================] - 73s 366ms/step - loss: 0.0902 - acc: 0.9674 - val_loss: 0.3833 - val_acc: 0.9108
# Epoch 27/100
# 200/200 [==============================] - 71s 357ms/step - loss: 0.0832 - acc: 0.9699 - val_loss: 0.6683 - val_acc: 0.9152
# Epoch 28/100
# 200/200 [==============================] - 72s 359ms/step - loss: 0.0835 - acc: 0.9697 - val_loss: 0.2677 - val_acc: 0.9106
# Epoch 29/100
# 200/200 [==============================] - 71s 354ms/step - loss: 0.0748 - acc: 0.9739 - val_loss: 0.3223 - val_acc: 0.8969
# Epoch 30/100
# 200/200 [==============================] - 74s 372ms/step - loss: 0.0797 - acc: 0.9723 - val_loss: 0.2171 - val_acc: 0.9110
# Epoch 31/100
# 200/200 [==============================] - 71s 357ms/step - loss: 0.0761 - acc: 0.9732 - val_loss: 10.8599 - val_acc: 0.4792
# Epoch 32/100
# 200/200 [==============================] - 74s 371ms/step - loss: 0.0720 - acc: 0.9758 - val_loss: 0.1460 - val_acc: 0.9075
# Epoch 33/100
# 200/200 [==============================] - 71s 357ms/step - loss: 0.0655 - acc: 0.9775 - val_loss: 0.2779 - val_acc: 0.9143
# Found 26098 images belonging to 2 classes.
# 204/204 [==============================] - 16s 76ms/step
# [[1.000 0.000]
#  [0.932 0.068]
#  [1.000 0.000]
#  ...
#  [0.005 0.995]
#  [0.005 0.995]
#  [0.343 0.657]]
# 100% 204/204 [00:30<00:00,  6.71it/s]
# [0 0 0 ... 1 1 1]
# [0 0 0 ... 1 1 1]
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.89     13198
#            1       0.84      0.97      0.90     12900
#
#     accuracy                           0.89     26098
#    macro avg       0.90      0.89      0.89     26098
# weighted avg       0.90      0.89      0.89     26098
#
# [[10828  2370]
#  [  417 12483]]
# AUROC: 0.958786
# 0.945000946522076
# test_acc:  0.8932102076787494
