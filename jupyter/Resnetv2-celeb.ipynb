# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import tarfile
tfile = tarfile.open("/content/gdrive/My Drive/Deep Learning Groupwork/Project/Data-Celeb.tar")
tfile.extractall()

# %%
training_dir = '/content/Data-Celeb/Train'
val_dir = '/content/Data-Celeb/Validation'
finetunedir = '/content/Data-Celeb/FineTune'
testdir = '/content/Data-Celeb/Test'

# %%
import os
from os import listdir
from os.path import isfile, join
mypath = '/content/Data-Celeb/Test/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/Test/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")
mypath = '/content/Data-Celeb/Train/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/Train/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/Validation/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/Validation/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/FineTune/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data-Celeb/FineTune/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")
# Out:
# /content/Data-Celeb/Test/Fake
# /content/Data-Celeb/Test/Real
# /content/Data-Celeb/Train/Fake
# /content/Data-Celeb/Train/Real
# /content/Data-Celeb/Validation/Real
# /content/Data-Celeb/Validation/Fake
# /content/Data-Celeb/FineTune/Real
# /content/Data-Celeb/FineTune/Fake

# %%
import os
os.chdir('/content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet')
print(os.getcwd())
# Out:
# /content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet

# %%
# !python3 pretrain.py -network='resnetV2' -train_dir='/content/Data-Celeb/Train' -val_dir='/content/Data-Celeb/Validation' -batch_size=128 -reduce_patience=100 -step=200 -epochs=100
# Out:
# Using TensorFlow backend.
# 2020-04-27 14:39:31.775408: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-27 14:39:37.107277: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-27 14:39:37.143762: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 14:39:37.144439: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-27 14:39:37.144482: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python3 test.py -test_dir='/content/Data-Celeb/Test' -model='/content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet/models/weights-resnetv2-celeb'
# Out:
# 2020-04-27 16:20:03.277891: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Found 25648 images belonging to 2 classes.
# 2020-04-27 16:20:08.450558: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-27 16:20:08.468685: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-27 16:20:08.469266: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %%
# !python3 fdft.py -model='/content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet/models/weights-resnetv2-celeb' -ft_dir='/content/Data-Celeb/FineTune' -val_dir='/content/Data-Celeb/Validation' -network='resnetV2' -test_dir='/content/Data-Celeb/Test'
# Out:
# 2020-04-28 04:25:11.474069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Found 2003 images belonging to 2 classes.
# Found 22196 images belonging to 2 classes.
# 2020-04-28 04:25:14.980551: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-28 04:25:15.004705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 04:25:15.005611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...
