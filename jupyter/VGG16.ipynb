# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tarfile
tfile = tarfile.open("/content/gdrive/My Drive/Deep Learning Groupwork/Project/Data.tar")
tfile.extractall()

# %%
training_dir = '/content/Data/Train'
val_dir = '/content/Data/Validation'
finetunedir = '/content/Data/FineTune'
testdir = '/content/Data/Test'

# %%
import os
from os import listdir
from os.path import isfile, join
mypath = '/content/Data/Test/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data/Test/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")
mypath = '/content/Data/Train/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data/Train/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data/Validation/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data/Validation/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data/FineTune/Real'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")

mypath = '/content/Data/FineTune/Fake'
print(mypath)
for f in listdir(mypath):
  #print(f[0])
  if f[0] == '.':
    try:
      os.remove(join(mypath, f))
    except: 
      print("file not deleted")
# Out:
# /content/Data/Test/Fake
# /content/Data/Test/Real
# /content/Data/Train/Fake
# /content/Data/Train/Real
# /content/Data/Validation/Real
# /content/Data/Validation/Fake
# /content/Data/FineTune/Real
# /content/Data/FineTune/Fake

# %%
import os
os.chdir('/content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet')
print(os.getcwd())
# Out:
# /content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet

# %%
# !python3 pretrain.py -network='vgg16' -train_dir='/content/Data/Train' -val_dir='/content/Data/Validation' -batch_size=128 -reduce_patience=100 -step=200 -epochs=100
# Out:
# Using TensorFlow backend.
# 2020-04-26 23:05:45.482557: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:05:49.444738: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-26 23:05:49.503200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:05:49.503787: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-04-26 23:05:49.503841: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:05:49.745044: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 23:05:49.881521: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-26 23:05:49.907034: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-26 23:05:50.194948: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-26 23:05:50.241369: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-26 23:05:50.756271: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-26 23:05:50.756425: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:05:50.757090: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:05:50.757586: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-26 23:05:50.757923: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-04-26 23:05:50.784015: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2000179999 Hz
# 2020-04-26 23:05:50.784229: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x27eebc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-26 23:05:50.784275: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-26 23:05:50.962429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:05:50.963110: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x27eed80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-26 23:05:50.963143: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-04-26 23:05:50.964217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:05:50.964768: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-04-26 23:05:50.964822: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:05:50.964857: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 23:05:50.964884: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-26 23:05:50.964912: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-26 23:05:50.964935: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-26 23:05:50.964957: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-26 23:05:50.964978: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-26 23:05:50.965055: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:05:50.965594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:05:50.966085: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-26 23:05:50.970518: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:05:57.700456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-26 23:05:57.700515: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-04-26 23:05:57.700533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-04-26 23:05:57.706044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:05:57.706660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:05:57.707156: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-26 23:05:57.707201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13970 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              8392704
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 2)                 8194
# =================================================================
# Total params: 39,896,898
# Trainable params: 39,896,898
# Non-trainable params: 0
# _________________________________________________________________
# 32
# Found 66329 images belonging to 2 classes.
# Found 20700 images belonging to 2 classes.
# Epoch 1/100
# 2020-04-26 23:06:01.705654: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 23:06:03.151469: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7

# %%
# !python3 test.py -test_dir='/content/Data/Test' -model='/content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet/models/weights-vgg16-million'
# Out:
# 2020-04-26 23:47:42.340538: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Found 16565 images belonging to 2 classes.
# 2020-04-26 23:47:47.057575: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-26 23:47:47.102464: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:47:47.103042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-26 23:47:47.103084: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:47:47.357009: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 23:47:47.467722: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-26 23:47:47.518152: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-26 23:47:48.051556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-26 23:47:48.112500: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-26 23:47:48.626526: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-26 23:47:48.626721: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:47:48.627635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:47:48.628381: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-26 23:47:48.654407: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-04-26 23:47:48.654622: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x17a52c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-26 23:47:48.654651: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-26 23:47:48.814550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:47:48.815200: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x17a5d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-26 23:47:48.815228: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-04-26 23:47:48.816697: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:47:48.817217: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-26 23:47:48.817258: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:47:48.817305: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 23:47:48.817328: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-26 23:47:48.817350: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-26 23:47:48.817369: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-26 23:47:48.817389: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-26 23:47:48.817410: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-26 23:47:48.817485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:47:48.818010: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:47:48.818525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-26 23:47:48.820863: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:47:55.211843: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-26 23:47:55.211899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-04-26 23:47:55.211912: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-04-26 23:47:55.217062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:47:55.217718: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:47:55.218227: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-26 23:47:55.218274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14974 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-04-26 23:48:04.011990: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 23:48:05.423377: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 130/130 [==============================] - 7s 51ms/step
# [[0.485 0.515]
#  [0.485 0.515]
#  [0.485 0.515]
#  ...
#  [0.485 0.515]
#  [0.485 0.515]
#  [0.485 0.515]]
# 100% 130/130 [00:14<00:00,  9.00it/s]
# [1 1 1 ... 1 1 1]
# [0 0 0 ... 1 1 1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      7986
#            1       0.52      1.00      0.68      8579
#
#     accuracy                           0.52     16565
#    macro avg       0.26      0.50      0.34     16565
# weighted avg       0.27      0.52      0.35     16565
#
# [[   0 7986]
#  [   0 8579]]
# AUROC: 0.500000
# 1.0148716270923615
# test_acc:  0.5178991850286749

# %%
# !python3 fdft.py -model='/content/gdrive/My Drive/Deep Learning Groupwork/Project/Code - Kabir/Code/FDFtNet/models/weights-vgg16-million' -ft_dir='/content/Data/FineTune' -val_dir='/content/Data/Validation' -network='vgg16' -test_dir='/content/Data/Test'
# Out:
# 2020-04-26 23:48:33.551200: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Found 1932 images belonging to 2 classes.
# Found 20700 images belonging to 2 classes.
# 2020-04-26 23:48:39.623991: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-26 23:48:39.638142: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:48:39.638709: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-26 23:48:39.638748: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:48:39.640127: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 23:48:39.656267: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-26 23:48:39.656685: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-26 23:48:39.658683: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-26 23:48:39.659703: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-26 23:48:39.663401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-26 23:48:39.663543: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:48:39.664109: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:48:39.664620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-26 23:48:39.670686: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-04-26 23:48:39.670887: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1f58d80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-26 23:48:39.670919: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-26 23:48:39.758670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:48:39.759484: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1f58bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-26 23:48:39.759519: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-04-26 23:48:39.759699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:48:39.760225: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-26 23:48:39.760264: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:48:39.760307: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 23:48:39.760327: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-26 23:48:39.760346: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-26 23:48:39.760369: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-26 23:48:39.760387: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-26 23:48:39.760406: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-26 23:48:39.760487: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:48:39.761023: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:48:39.761525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-26 23:48:39.761573: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-26 23:48:40.250931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-26 23:48:40.250989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-04-26 23:48:40.251002: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-04-26 23:48:40.251210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:48:40.251870: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 23:48:40.252392: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-26 23:48:40.252444: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14974 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# <tensorflow.python.keras.engine.training.Model object at 0x7f15adda9f28>
# (1, 1, 32, 4)
# (1, 1, 64, 8)
# (1, 1, 96, 12)
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# vgg16 (Model)                   (None, 2, 2, 512)    14714688    input_1[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 576)          1619456     vgg16[1][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 576)          85710       input_1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 576)          0           model_1[1][0]
#                                                                  model_2[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1154        add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2)            0           dense_1[0][0]
# ==================================================================================================
# Total params: 16,421,008
# Trainable params: 16,408,080
# Non-trainable params: 12,928
# __________________________________________________________________________________________________
# Epoch 1/100
# 2020-04-26 23:48:57.522854: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-26 23:48:57.771918: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 200/200 [==============================] - 65s 324ms/step - loss: 0.5415 - acc: 0.7392 - val_loss: 61.8658 - val_acc: 0.4818
# Epoch 2/100
# 200/200 [==============================] - 56s 280ms/step - loss: 0.4246 - acc: 0.8109 - val_loss: 0.1820 - val_acc: 0.5369
# Epoch 3/100
# 200/200 [==============================] - 55s 274ms/step - loss: 0.3856 - acc: 0.8348 - val_loss: 0.0265 - val_acc: 0.5382
# Epoch 4/100
# 200/200 [==============================] - 56s 279ms/step - loss: 0.3619 - acc: 0.8495 - val_loss: 0.1947 - val_acc: 0.7877
# Epoch 5/100
# 200/200 [==============================] - 55s 275ms/step - loss: 0.3183 - acc: 0.8674 - val_loss: 0.0181 - val_acc: 0.5294
# Epoch 6/100
# 200/200 [==============================] - 56s 278ms/step - loss: 0.3000 - acc: 0.8758 - val_loss: 0.1570 - val_acc: 0.7672
# Epoch 7/100
# 200/200 [==============================] - 55s 273ms/step - loss: 0.2676 - acc: 0.8926 - val_loss: 0.0240 - val_acc: 0.5549
# Epoch 8/100
# 200/200 [==============================] - 56s 279ms/step - loss: 0.2681 - acc: 0.8956 - val_loss: 1.2071 - val_acc: 0.7964
# Epoch 9/100
# 200/200 [==============================] - 55s 274ms/step - loss: 0.2491 - acc: 0.9046 - val_loss: 5.5483 - val_acc: 0.5714
# Epoch 10/100
# 200/200 [==============================] - 56s 278ms/step - loss: 0.2462 - acc: 0.9037 - val_loss: 0.5939 - val_acc: 0.8575
# Epoch 11/100
# 200/200 [==============================] - 54s 272ms/step - loss: 0.2060 - acc: 0.9194 - val_loss: 0.5763 - val_acc: 0.8548
# Epoch 12/100
# 200/200 [==============================] - 56s 279ms/step - loss: 0.2057 - acc: 0.9202 - val_loss: 1.1330 - val_acc: 0.8378
# Epoch 13/100
# 200/200 [==============================] - 55s 273ms/step - loss: 0.1817 - acc: 0.9313 - val_loss: 4.5280 - val_acc: 0.6469
# Epoch 14/100
# 200/200 [==============================] - 56s 278ms/step - loss: 0.1785 - acc: 0.9328 - val_loss: 4.7715 - val_acc: 0.6187
# Epoch 15/100
# 200/200 [==============================] - 55s 273ms/step - loss: 0.1703 - acc: 0.9343 - val_loss: 0.3434 - val_acc: 0.8692
# Epoch 16/100
# 200/200 [==============================] - 55s 277ms/step - loss: 0.1646 - acc: 0.9387 - val_loss: 0.9985 - val_acc: 0.8593
# Epoch 17/100
# 200/200 [==============================] - 55s 273ms/step - loss: 0.1472 - acc: 0.9450 - val_loss: 1.0224 - val_acc: 0.8600
# Epoch 18/100
# 200/200 [==============================] - 56s 278ms/step - loss: 0.1691 - acc: 0.9377 - val_loss: 1.8400 - val_acc: 0.7951
# Epoch 19/100
# 200/200 [==============================] - 55s 273ms/step - loss: 0.1374 - acc: 0.9505 - val_loss: 1.6629 - val_acc: 0.8209
# Epoch 20/100
# 200/200 [==============================] - 56s 278ms/step - loss: 0.1371 - acc: 0.9492 - val_loss: 2.2294 - val_acc: 0.7955
# Epoch 21/100
# 200/200 [==============================] - 55s 274ms/step - loss: 0.1606 - acc: 0.9433 - val_loss: 0.3920 - val_acc: 0.8729
# Epoch 22/100
# 200/200 [==============================] - 55s 277ms/step - loss: 0.1316 - acc: 0.9519 - val_loss: 0.9647 - val_acc: 0.8470
# Epoch 23/100
# 200/200 [==============================] - 55s 273ms/step - loss: 0.1387 - acc: 0.9502 - val_loss: 0.3004 - val_acc: 0.8588
# Epoch 24/100
# 200/200 [==============================] - 56s 278ms/step - loss: 0.1226 - acc: 0.9575 - val_loss: 0.4850 - val_acc: 0.8440
# Epoch 25/100
# 200/200 [==============================] - 55s 275ms/step - loss: 0.1166 - acc: 0.9604 - val_loss: 0.7924 - val_acc: 0.8743
# Epoch 26/100
# 200/200 [==============================] - 56s 279ms/step - loss: 0.1174 - acc: 0.9587 - val_loss: 3.5215 - val_acc: 0.7417
# Epoch 27/100
# 200/200 [==============================] - 55s 274ms/step - loss: 0.1211 - acc: 0.9575 - val_loss: 3.5117 - val_acc: 0.7385
# Epoch 28/100
# 200/200 [==============================] - 56s 278ms/step - loss: 0.1373 - acc: 0.9533 - val_loss: 1.0581 - val_acc: 0.8456
# Epoch 29/100
# 200/200 [==============================] - 55s 274ms/step - loss: 0.1141 - acc: 0.9601 - val_loss: 0.8373 - val_acc: 0.8723
# Epoch 30/100
# 200/200 [==============================] - 56s 279ms/step - loss: 0.0858 - acc: 0.9693 - val_loss: 0.2109 - val_acc: 0.8255
# Epoch 31/100
# 200/200 [==============================] - 55s 275ms/step - loss: 0.1055 - acc: 0.9635 - val_loss: 0.6794 - val_acc: 0.8843
# Epoch 32/100
# 200/200 [==============================] - 56s 278ms/step - loss: 0.0858 - acc: 0.9705 - val_loss: 0.4492 - val_acc: 0.8689
# Epoch 33/100
# 200/200 [==============================] - 55s 274ms/step - loss: 0.1046 - acc: 0.9649 - val_loss: 0.8003 - val_acc: 0.8779
# Epoch 34/100
# 200/200 [==============================] - 56s 279ms/step - loss: 0.0744 - acc: 0.9748 - val_loss: 0.8223 - val_acc: 0.8768
# Epoch 35/100
# 200/200 [==============================] - 55s 273ms/step - loss: 0.0758 - acc: 0.9737 - val_loss: 0.3755 - val_acc: 0.8723
# Epoch 36/100
# 200/200 [==============================] - 56s 280ms/step - loss: 0.0941 - acc: 0.9687 - val_loss: 0.3672 - val_acc: 0.8600
# Epoch 37/100
# 200/200 [==============================] - 55s 274ms/step - loss: 0.1047 - acc: 0.9652 - val_loss: 0.7524 - val_acc: 0.8835
# Epoch 38/100
# 200/200 [==============================] - 55s 277ms/step - loss: 0.0942 - acc: 0.9674 - val_loss: 0.5105 - val_acc: 0.8761
# Epoch 39/100
# 200/200 [==============================] - 55s 273ms/step - loss: 0.0710 - acc: 0.9775 - val_loss: 2.2163 - val_acc: 0.8258
# Epoch 40/100
# 200/200 [==============================] - 56s 278ms/step - loss: 0.0967 - acc: 0.9673 - val_loss: 1.3278 - val_acc: 0.8714
# Epoch 41/100
# 200/200 [==============================] - 55s 273ms/step - loss: 0.0883 - acc: 0.9722 - val_loss: 0.5672 - val_acc: 0.8657
# Found 16565 images belonging to 2 classes.
# 130/130 [==============================] - 8s 59ms/step
# [[1.000 0.000]
#  [0.516 0.484]
#  [0.907 0.093]
#  ...
#  [0.000 1.000]
#  [0.000 1.000]
#  [0.000 1.000]]
# 100% 130/130 [00:16<00:00,  8.09it/s]
# [0 0 0 ... 1 1 1]
# [0 0 0 ... 1 1 1]
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87      7986
#            1       0.86      0.92      0.89      8579
#
#     accuracy                           0.88     16565
#    macro avg       0.88      0.88      0.88     16565
# weighted avg       0.88      0.88      0.88     16565
#
# [[6657 1329]
#  [ 698 7881]]
# AUROC: 0.952657
# 0.7886006697058766
# test_acc:  0.8776335647449441
